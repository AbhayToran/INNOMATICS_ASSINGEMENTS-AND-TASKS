# %% [markdown]
# # **TASK 2**
#
# -->**Abhay Toran**

# %% [markdown]
# **Problem 1: Given a sentence, identify all unique words and display:**
#
# **Input**
#
# Enter sentence: python is easy and python is powerful
#
# **Expected Output**
#
# Unique words count: 5
# Unique words: {'python', 'is', 'easy', 'and', 'powerful'}

# %%
# Unique word count
# Taking Inputs from user and spliting it into individual words and then applying set operation for finding uniqueness...
word = input("Enter sentence: ")
n = word.split()
n = set(n)
print("Unique words count: ",len(n))
print("Unique words: ",n)
# Out:
# Enter sentence: python is easy and python is powerful
# Unique words count:  5
# Unique words:  {'and', 'is', 'powerful', 'easy', 'python'}

# %% [markdown]
# **Problem 2: Highest Salary from Employee Data**
#
# Store employee names and their salaries, and determine which employee has the highest salary.
#
# **Input**
#
# employees = {
#     "Ravi": 75000,
#     "Anita": 68000,
#     "Kiran": 72000
# }
#
# **Expected Output**
#
# Highest Salary: Ravi - 75000

# %%
#Taking empty dictionary, then taking n inputs from user with there name and salary which gets add in dictionary
#After that storeing keys in list_keys and storeing values in list_values
#index variable store the index of maximum salary
dic = {}
n = int(input())
for i in range(n):
  name = input()
  salary = int(input())
  dic[name] = salary
list_keys = list(dic.keys())
list_values = list(dic.values())
index = list_values.index(max(list_values))
print(f"Highest Salary: {list_keys[index]}-{list_values[index]}")
# Out:
# 3
# Ravi
# 75000
# Anita
# 68000
# Kiran
# 72000
# Highest Salary: Ravi-75000

# %% [markdown]
# **Problem 3: Find Maximum and Minimum Values**
#
# **Input Format**
#
# A list of integers where each element represents a numeric value.
# Example Input
# numbers = [45, 22, 89, 10, 66]
#
# **Expected Output**
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
#Taking n inputs and printing max and min elements from it
n = int(input())
li = []
for i in range(n):
  val = int(input())
  li.append(val)
print(f"List: {li}")
print(f"Max: {max(li)}")
print(f"Min: {min(li)}")
# Out:
# 5
# 45
# 22
# 89
# 10
# 66
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# Problem Statement 4:
# Count how many products have a price greater than 1000. **bold text**
#
# **Input**
#
# prices = [450, 1200, 899, 1500, 300]
#
# **Expected Output**
#
# Products above 1000: 2

# %%
#Taking n inputs from the user, counting if the price is greater tha 1000.
#At last printing the count value
n = int(input())
prices = []
for i in range(n):
  val = int(input())
  prices.append(val)
count = 0
for i in prices:
  if(i>1000):
    count+=1
print(f"Products above 1000: {count}")
# Out:
# 5
# 450
# 1200
# 899
# 1500
# 300
# Products above 1000: 2

# %% [markdown]
# **Problem 5: Calculate Attendance Percentage**
#
# Problem Statement
#
# Calculate the attendance percentage from a list containing "P" (Present) and "A" (Absent).
#
# **Input**
#
# attendance = ["P", "P", "A", "P", "P"]
#
# **Expected Output**
#
# Attendance Percentage: 80.0

# %%
n = int(input())
attendence = []
for i in range(n):
  val = input()
  attendence.append(val)
count_present = 0
for i in attendence:
  if i=="P":
    count_present+=1
print(count_present)
print(f"Attendence Percentage: {(count_present/len(attendence))*100:.2f}")
# Out:
# 5
# P
# A
# P
# P
# P
# 4
# Attendence Percentage: 80.00

# %% [markdown]
# **Problem 6: Remove Duplicate Phone Numbers**
#
# **Example Input**
#
# phone_numbers = [9876543210, 9123456789, 9876543210]
#
# **Expected Output**
#
# Unique phone numbers: {9876543210, 9123456789}

# %%
#Taking n inputs and appending in list, afterwards printing the set of phone_num
n = int(input())
phone_num = []
for i in range(n):
  val = int(input())
  phone_num.append(val)
print(f"Unique phone numbers: {set(phone_num)}")
# Out:
# 3
# 9876543210
# 9123456789
# 9876543210
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# **Problem 7: Count Character Frequency**
#
# **Expected Output**
#
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
#Taking the input and storeing each char in dic...
n = input()
dic = {}
for i in n:
  dic[i] = dic.get(i,0)+1
print(dic)
# Out:
# python program
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 1, ' ': 1, 'r': 2, 'g': 1, 'a': 1, 'm': 1}

# %% [markdown]
# **Problem 8: Convert List to Tuple**
#
# **Expected Output**
#
# Tuple: (10, 20, 30)

# %%
#Taking n inputs and stroreing values in list and then printing tuple of that value
n = int(input())
li = []
for i in range(n):
  val = int(input())
  li.append(val)
print(f"Tuple: {tuple(li)}2")
# Out:
# 3
# 10
# 20
# 30
# Tuple: (10, 20, 30)

# %% [markdown]
# **Problem 9: Check if a Key Exists in a Dictionary**
#
# Problem Statement
# Check whether a specific key exists in a dictionary.
#
# **Expected Output**
#
# Employee exists

# %%
#Taking n inputs and storeing in dictionary, after that checking wheather the key exists or not using membership operator
n = int(input())
dic = {}
for i in range(n):
  emp = input()
  salary = int(input())
  dic[emp] = salary
check = input()
if(check in dic):
  print("Employee exists")
else:
  print("No such Key")
# Out:
# 3
# Abhay
# 70000
# Kiran
# 45000
# Ajay
# 50000
# Abhay
# Employee exists

# %% [markdown]
# **Problem 10: Calculate Average Marks**
#
# **Expected Output**
#
# Average Marks: 72.5

# %%
n = int(input())
li = []
for i in range(n):
  marks = float(input())
  li.append(marks)
print(f"Average Marks: {sum(li)/n:.2f}")
# Out:
# 5
# 92.5
# 67
# 87
# 90
# 75
# Average Marks: 82.30
